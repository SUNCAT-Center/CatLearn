# %% [markdown]
# # Voronoi Feature Generators <a name="head"></a>
#
# In this tutorial, we will look at generating features from a database of organic donor-acceptor molecules from the [Computational Materials Repository](https://cmrdb.fysik.dtu.dk/?project=solar). This has been downloaded in the [ase-db](https://wiki.fysik.dtu.dk/ase/ase/db/db.html#module-ase.db) format so first off we load the atoms objects and get a target property. Then we convert the atoms objects into a feature array and test out a couple of different models.
#
# This tutorial will give an indication of one way in which it is possible to handle atoms objects of different sizes. In particular, we focus on a feature set that scales with the number of atoms. We pad the feature vectors to a constant size to overcome this problem.
#
# ## Table of Contents
# [(Back to top)](#head)
#
# -   [Requirements](#requirements)
# -   [Data Setup](#data-setup)
# -   [Feature Generation](#feature-generation)
# -   [Predictions](#predictions)
# -   [Cross-validation](#cross-validation)
#
# ## Requirements <a name="requirements"></a>
# [(Back to top)](#head)
#
# -   [AtoML](https://gitlab.com/atoml/AtoML)
# -   [ASE](https://wiki.fysik.dtu.dk/ase/)
# -   [numpy](http://www.numpy.org/)
# -   [matplotlib](https://matplotlib.org/)
# -   [pandas](http://pandas.pydata.org/)
# -   [seaborn](http://seaborn.pydata.org/index.html)
#
# ## Data Setup <a name="data-setup"></a>
# [(Back to top)](#head)
#
# First, we need to import some functions.

# %%
import ase
import random
from atoml.fingerprint.voro_fingerprint import VoronoiFingerprintGenerator

# %%
# Connect the ase-db.
db = ase.db.connect('../../data/cubic_perovskites.db')
atoms = list(db.select(combination= 'ABO3'))
random.shuffle(atoms)

# Compile a list of atoms and target values.
alist = []
for row in atoms:
    try:
        alist.append(row.toatoms())
    except AttributeError:
        continue

# Analyze the size of molecules in the db.
print('pulled {} molecules from db'.format(len(alist)))
size = []
for a in alist:
    size.append(len(a))

print('min: {0}, mean: {1:.0f}, max: {2} molecule size'.format(
    min(size), sum(size)/len(size), max(size)))
# Out:
# pulled 2704 molecules from db
# min: 5, mean: 5, max: 5 molecule size

# %%
voro=VoronoiFingerprintGenerator(alist, )

# %%
voro.generate()
# Out:
# Generate Voronoi fingerprint of 2704 structures
#       mean_EffectiveCoordination  var_EffectiveCoordination  \
# 0                            NaN                        NaN
# 1                            NaN                        NaN
# 2                            NaN                        NaN
# 3                            NaN                        NaN
# 4                            NaN                        NaN
# 5                            NaN                        NaN
# 6                            NaN                        NaN
# 7                            NaN                        NaN
# 8                            NaN                        NaN
# 9                            NaN                        NaN
# 10                           NaN                        NaN
# 11                           NaN                        NaN
# 12                           NaN                        NaN
# 13                           NaN                        NaN
# 14                           NaN                        NaN
# 15                           NaN                        NaN
# 16                           NaN                        NaN
# 17                           NaN                        NaN
# 18                           NaN                        NaN
# 19                           NaN                        NaN
# 20                           NaN                        NaN
# 21                           NaN                        NaN
# 22                           NaN                        NaN
# 23                           NaN                        NaN
# 24                           NaN                        NaN
# 25                           NaN                        NaN
# 26                           NaN                        NaN
# 27                           NaN                        NaN
# 28                           NaN                        NaN
# 29                           NaN                        NaN
# ...                          ...                        ...
# 2674                         NaN                        NaN
# 2675                         NaN                        NaN
# 2676                         NaN                        NaN
# 2677                         NaN                        NaN
# 2678                         NaN                        NaN
# 2679                         NaN                        NaN
# 2680                         NaN                        NaN
# 2681                         NaN                        NaN
# 2682                         NaN                        NaN
# 2683                         NaN                        NaN
# 2684                         NaN                        NaN
# 2685                         NaN                        NaN
# 2686                         NaN                        NaN
# 2687                         NaN                        NaN
# 2688                         NaN                        NaN
# 2689                         NaN                        NaN
# 2690                         NaN                        NaN
# 2691                         NaN                        NaN
# 2692                         NaN                        NaN
# 2693                         NaN                        NaN
# 2694                         NaN                        NaN
# 2695                         NaN                        NaN
# 2696                         NaN                        NaN
# 2697                         NaN                        NaN
# 2698                         NaN                        NaN
# 2699                         NaN                        NaN
# 2700                         NaN                        NaN
# 2701                         NaN                        NaN
# 2702                         NaN                        NaN
# 2703                         NaN                        NaN
#
#       min_EffectiveCoordination  max_EffectiveCoordination  \
# 0                           NaN                        NaN
# 1                           NaN                        NaN
# 2                           NaN                        NaN
# 3                           NaN                        NaN
# 4                           NaN                        NaN
# 5                           NaN                        NaN
# 6                           NaN                        NaN
# 7                           NaN                        NaN
# 8                           NaN                        NaN
# 9                           NaN                        NaN
# 10                          NaN                        NaN
# 11                          NaN                        NaN
# 12                          NaN                        NaN
# 13                          NaN                        NaN
# 14                          NaN                        NaN
# 15                          NaN                        NaN
# 16                          NaN                        NaN
# 17                          NaN                        NaN
# 18                          NaN                        NaN
# 19                          NaN                        NaN
# 20                          NaN                        NaN
# 21                          NaN                        NaN
# 22                          NaN                        NaN
# 23                          NaN                        NaN
# 24                          NaN                        NaN
# 25                          NaN                        NaN
# 26                          NaN                        NaN
# 27                          NaN                        NaN
# 28                          NaN                        NaN
# 29                          NaN                        NaN
# ...                         ...                        ...
# 2674                        NaN                        NaN
# 2675                        NaN                        NaN
# 2676                        NaN                        NaN
# 2677                        NaN                        NaN
# 2678                        NaN                        NaN
# 2679                        NaN                        NaN
# 2680                        NaN                        NaN
# 2681                        NaN                        NaN
# 2682                        NaN                        NaN
# 2683                        NaN                        NaN
# 2684                        NaN                        NaN
# 2685                        NaN                        NaN
# 2686                        NaN                        NaN
# 2687                        NaN                        NaN
# 2688                        NaN                        NaN
# 2689                        NaN                        NaN
# 2690                        NaN                        NaN
# 2691                        NaN                        NaN
# 2692                        NaN                        NaN
# 2693                        NaN                        NaN
# 2694                        NaN                        NaN
# 2695                        NaN                        NaN
# 2696                        NaN                        NaN
# 2697                        NaN                        NaN
# 2698                        NaN                        NaN
# 2699                        NaN                        NaN
# 2700                        NaN                        NaN
# 2701                        NaN                        NaN
# 2702                        NaN                        NaN
# 2703                        NaN                        NaN
#
#       var_MeanBondLength  min_MeanBondLength  max_MeanBondLength  \
# 0                    NaN                 NaN                 NaN
# 1                    NaN                 NaN                 NaN
# 2                    NaN                 NaN                 NaN
# 3                    NaN                 NaN                 NaN
# 4                    NaN                 NaN                 NaN
# 5                    NaN                 NaN                 NaN
# 6                    NaN                 NaN                 NaN
# 7                    NaN                 NaN                 NaN
# 8                    NaN                 NaN                 NaN
# 9                    NaN                 NaN                 NaN
# 10                   NaN                 NaN                 NaN
# 11                   NaN                 NaN                 NaN
# 12                   NaN                 NaN                 NaN
# 13                   NaN                 NaN                 NaN
# 14                   NaN                 NaN                 NaN
# 15                   NaN                 NaN                 NaN
# 16                   NaN                 NaN                 NaN
# 17                   NaN                 NaN                 NaN
# 18                   NaN                 NaN                 NaN
# 19                   NaN                 NaN                 NaN
# 20                   NaN                 NaN                 NaN
# 21                   NaN                 NaN                 NaN
# 22                   NaN                 NaN                 NaN
# 23                   NaN                 NaN                 NaN
# 24                   NaN                 NaN                 NaN
# 25                   NaN                 NaN                 NaN
# 26                   NaN                 NaN                 NaN
# 27                   NaN                 NaN                 NaN
# 28                   NaN                 NaN                 NaN
# 29                   NaN                 NaN                 NaN
# ...                  ...                 ...                 ...
# 2674                 NaN                 NaN                 NaN
# 2675                 NaN                 NaN                 NaN
# 2676                 NaN                 NaN                 NaN
# 2677                 NaN                 NaN                 NaN
# 2678                 NaN                 NaN                 NaN
# 2679                 NaN                 NaN                 NaN
# 2680                 NaN                 NaN                 NaN
# 2681                 NaN                 NaN                 NaN
# 2682                 NaN                 NaN                 NaN
# 2683                 NaN                 NaN                 NaN
# 2684                 NaN                 NaN                 NaN
# 2685                 NaN                 NaN                 NaN
# 2686                 NaN                 NaN                 NaN
# 2687                 NaN                 NaN                 NaN
# 2688                 NaN                 NaN                 NaN
# 2689                 NaN                 NaN                 NaN
# 2690                 NaN                 NaN                 NaN
# 2691                 NaN                 NaN                 NaN
# 2692                 NaN                 NaN                 NaN
# 2693                 NaN                 NaN                 NaN
# 2694                 NaN                 NaN                 NaN
# 2695                 NaN                 NaN                 NaN
# 2696                 NaN                 NaN                 NaN
# 2697                 NaN                 NaN                 NaN
# 2698                 NaN                 NaN                 NaN
# 2699                 NaN                 NaN                 NaN
# 2700                 NaN                 NaN                 NaN
# 2701                 NaN                 NaN                 NaN
# 2702                 NaN                 NaN                 NaN
# 2703                 NaN                 NaN                 NaN
#
#       mean_BondLengthVariation  var_BondLengthVariation  \
# 0                          NaN                      NaN
# 1                          NaN                      NaN
# 2                          NaN                      NaN
# 3                          NaN                      NaN
# 4                          NaN                      NaN
# 5                          NaN                      NaN
# 6                          NaN                      NaN
# 7                          NaN                      NaN
# 8                          NaN                      NaN
# 9                          NaN                      NaN
# 10                         NaN                      NaN
# 11                         NaN                      NaN
# 12                         NaN                      NaN
# 13                         NaN                      NaN
# 14                         NaN                      NaN
# 15                         NaN                      NaN
# 16                         NaN                      NaN
# 17                         NaN                      NaN
# 18                         NaN                      NaN
# 19                         NaN                      NaN
# 20                         NaN                      NaN
# 21                         NaN                      NaN
# 22                         NaN                      NaN
# 23                         NaN                      NaN
# 24                         NaN                      NaN
# 25                         NaN                      NaN
# 26                         NaN                      NaN
# 27                         NaN                      NaN
# 28                         NaN                      NaN
# 29                         NaN                      NaN
# ...                        ...                      ...
# 2674                       NaN                      NaN
# 2675                       NaN                      NaN
# 2676                       NaN                      NaN
# 2677                       NaN                      NaN
# 2678                       NaN                      NaN
# 2679                       NaN                      NaN
# 2680                       NaN                      NaN
# 2681                       NaN                      NaN
# 2682                       NaN                      NaN
# 2683                       NaN                      NaN
# 2684                       NaN                      NaN
# 2685                       NaN                      NaN
# 2686                       NaN                      NaN
# 2687                       NaN                      NaN
# 2688                       NaN                      NaN
# 2689                       NaN                      NaN
# 2690                       NaN                      NaN
# 2691                       NaN                      NaN
# 2692                       NaN                      NaN
# 2693                       NaN                      NaN
# 2694                       NaN                      NaN
# 2695                       NaN                      NaN
# 2696                       NaN                      NaN
# 2697                       NaN                      NaN
# 2698                       NaN                      NaN
# 2699                       NaN                      NaN
# 2700                       NaN                      NaN
# 2701                       NaN                      NaN
# 2702                       NaN                      NaN
# 2703                       NaN                      NaN
#
#       min_BondLengthVariation   ...    min_SpaceGroupNumber  \
# 0                         NaN   ...                    12.0
# 1                         NaN   ...                    12.0
# 2                         NaN   ...                    12.0
# 3                         NaN   ...                    12.0
# 4                         NaN   ...                    12.0
# 5                         NaN   ...                    12.0
# 6                         NaN   ...                    12.0
# 7                         NaN   ...                    12.0
# 8                         NaN   ...                    12.0
# 9                         NaN   ...                    12.0
# 10                        NaN   ...                    12.0
# 11                        NaN   ...                    12.0
# 12                        NaN   ...                    12.0
# 13                        NaN   ...                    12.0
# 14                        NaN   ...                    12.0
# 15                        NaN   ...                    12.0
# 16                        NaN   ...                    12.0
# 17                        NaN   ...                    12.0
# 18                        NaN   ...                    12.0
# 19                        NaN   ...                    12.0
# 20                        NaN   ...                    12.0
# 21                        NaN   ...                    12.0
# 22                        NaN   ...                    12.0
# 23                        NaN   ...                    12.0
# 24                        NaN   ...                    12.0
# 25                        NaN   ...                    12.0
# 26                        NaN   ...                    12.0
# 27                        NaN   ...                    12.0
# 28                        NaN   ...                    12.0
# 29                        NaN   ...                    12.0
# ...                       ...   ...                     ...
# 2674                      NaN   ...                    12.0
# 2675                      NaN   ...                    12.0
# 2676                      NaN   ...                    12.0
# 2677                      NaN   ...                    12.0
# 2678                      NaN   ...                    12.0
# 2679                      NaN   ...                    12.0
# 2680                      NaN   ...                    12.0
# 2681                      NaN   ...                    12.0
# 2682                      NaN   ...                    12.0
# 2683                      NaN   ...                    12.0
# 2684                      NaN   ...                    12.0
# 2685                      NaN   ...                    12.0
# 2686                      NaN   ...                    12.0
# 2687                      NaN   ...                    12.0
# 2688                      NaN   ...                    12.0
# 2689                      NaN   ...                    12.0
# 2690                      NaN   ...                    12.0
# 2691                      NaN   ...                    12.0
# 2692                      NaN   ...                    12.0
# 2693                      NaN   ...                    12.0
# 2694                      NaN   ...                    12.0
# 2695                      NaN   ...                    12.0
# 2696                      NaN   ...                    12.0
# 2697                      NaN   ...                    12.0
# 2698                      NaN   ...                    12.0
# 2699                      NaN   ...                    12.0
# 2700                      NaN   ...                    12.0
# 2701                      NaN   ...                    12.0
# 2702                      NaN   ...                    12.0
# 2703                      NaN   ...                    12.0
#
#       most_SpaceGroupNumber  frac_sValence  frac_pValence  frac_dValence  \
# 0                      12.0       0.277778       0.416667       0.305556
# 1                      12.0       0.400000       0.560000       0.040000
# 2                      12.0       0.169492       0.254237       0.338983
# 3                      12.0       0.256410       0.307692       0.435897
# 4                      12.0       0.285714       0.428571       0.285714
# 5                      12.0       0.200000       0.266667       0.222222
# 6                      12.0       0.204082       0.244898       0.265306
# 7                      12.0       0.200000       0.260000       0.260000
# 8                      12.0       0.281250       0.375000       0.343750
# 9                      12.0       0.312500       0.375000       0.312500
# 10                     12.0       0.294118       0.411765       0.294118
# 11                     12.0       0.191489       0.255319       0.255319
# 12                     12.0       0.227273       0.272727       0.181818
# 13                     12.0       0.333333       0.466667       0.200000
# 14                     12.0       0.243902       0.390244       0.365854
# 15                     12.0       0.172414       0.241379       0.344828
# 16                     12.0       0.172414       0.241379       0.344828
# 17                     12.0       0.242424       0.363636       0.393939
# 18                     12.0       0.222222       0.333333       0.444444
# 19                     12.0       0.409091       0.590909       0.000000
# 20                     12.0       0.200000       0.300000       0.500000
# 21                     12.0       0.169811       0.226415       0.339623
# 22                     12.0       0.204082       0.244898       0.265306
# 23                     12.0       0.189189       0.324324       0.486486
# 24                     12.0       0.333333       0.481481       0.185185
# 25                     12.0       0.416667       0.500000       0.083333
# 26                     12.0       0.155172       0.258621       0.344828
# 27                     12.0       0.160714       0.232143       0.357143
# 28                     12.0       0.147059       0.191176       0.250000
# 29                     12.0       0.191489       0.297872       0.212766
# ...                     ...            ...            ...            ...
# 2674                   12.0       0.428571       0.571429       0.000000
# 2675                   12.0       0.416667       0.583333       0.000000
# 2676                   12.0       0.263158       0.315789       0.421053
# 2677                   12.0       0.256410       0.333333       0.410256
# 2678                   12.0       0.186047       0.348837       0.465116
# 2679                   12.0       0.250000       0.350000       0.400000
# 2680                   12.0       0.232558       0.279070       0.162791
# 2681                   12.0       0.209302       0.279070       0.186047
# 2682                   12.0       0.370370       0.444444       0.185185
# 2683                   12.0       0.219512       0.292683       0.146341
# 2684                   12.0       0.191489       0.255319       0.255319
# 2685                   12.0       0.163636       0.218182       0.363636
# 2686                   12.0       0.166667       0.266667       0.333333
# 2687                   12.0       0.296296       0.444444       0.259259
# 2688                   12.0       0.303030       0.393939       0.303030
# 2689                   12.0       0.188679       0.283019       0.264151
# 2690                   12.0       0.333333       0.400000       0.266667
# 2691                   12.0       0.270270       0.459459       0.270270
# 2692                   12.0       0.344828       0.413793       0.241379
# 2693                   12.0       0.181818       0.272727       0.227273
# 2694                   12.0       0.428571       0.571429       0.000000
# 2695                   12.0       0.281250       0.375000       0.343750
# 2696                   12.0       0.344828       0.413793       0.241379
# 2697                   12.0       0.277778       0.444444       0.277778
# 2698                   12.0       0.285714       0.428571       0.285714
# 2699                   12.0       0.333333       0.400000       0.266667
# 2700                   12.0       0.225000       0.300000       0.125000
# 2701                   12.0       0.208333       0.291667       0.208333
# 2702                   12.0       0.434783       0.521739       0.043478
# 2703                   12.0       0.209302       0.372093       0.418605
#
#       frac_fValence  CanFormIonic  MaxIonicChar  MeanIonicChar      id
# 0          0.000000           1.0      0.660947       0.249630     0.0
# 1          0.000000           0.0      0.660947       0.271599     1.0
# 2          0.237288           1.0      0.404527       0.189077     2.0
# 3          0.000000           0.0      0.551131       0.242710     3.0
# 4          0.000000           0.0      0.774266       0.287965     4.0
# 5          0.311111           0.0      0.660947       0.242443     5.0
# 6          0.285714           1.0      0.455779       0.188003     6.0
# 7          0.280000           0.0      0.609724       0.264711     7.0
# 8          0.000000           0.0      0.660947       0.269146     8.0
# 9          0.000000           0.0      0.678329       0.294025     9.0
# 10         0.000000           1.0      0.787757       0.308269    10.0
# 11         0.297872           0.0      0.681744       0.275453    11.0
# 12         0.318182           0.0      0.609724       0.288124    12.0
# 13         0.000000           1.0      0.476922       0.221906    13.0
# 14         0.000000           1.0      0.590585       0.234368    14.0
# 15         0.241379           1.0      0.551131       0.204630    15.0
# 16         0.241379           1.0      0.404527       0.193146    16.0
# 17         0.000000           1.0      0.559139       0.217028    17.0
# 18         0.000000           1.0      0.476922       0.193747    18.0
# 19         0.000000           0.0      0.820234       0.344515    19.0
# 20         0.000000           0.0      0.551131       0.214692    20.0
# 21         0.264151           1.0      0.443019       0.157877    21.0
# 22         0.285714           0.0      0.609724       0.275442    22.0
# 23         0.000000           1.0      0.319141       0.145281    23.0
# 24         0.000000           0.0      0.387374       0.173917    24.0
# 25         0.000000           1.0      0.787757       0.353043    25.0
# 26         0.241379           1.0      0.383086       0.140597    26.0
# 27         0.250000           1.0      0.497872       0.174241    27.0
# 28         0.411765           1.0      0.563121       0.218196    28.0
# 29         0.297872           0.0      0.820234       0.295240    29.0
# ...             ...           ...           ...            ...     ...
# 2674       0.000000           0.0      0.792998       0.379389  2674.0
# 2675       0.000000           1.0      0.774266       0.307836  2675.0
# 2676       0.000000           1.0      0.443019       0.212649  2676.0
# 2677       0.000000           1.0      0.497872       0.234001  2677.0
# 2678       0.000000           1.0      0.383086       0.168983  2678.0
# 2679       0.000000           1.0      0.476922       0.215998  2679.0
# 2680       0.325581           1.0      0.803211       0.297273  2680.0
# 2681       0.325581           0.0      0.609724       0.278150  2681.0
# 2682       0.000000           1.0      0.803211       0.342765  2682.0
# 2683       0.341463           0.0      0.827201       0.306455  2683.0
# 2684       0.297872           1.0      0.681744       0.277851  2684.0
# 2685       0.254545           0.0      0.447278       0.204633  2685.0
# 2686       0.233333           1.0      0.563121       0.219805  2686.0
# 2687       0.000000           0.0      0.792998       0.293460  2687.0
# 2688       0.000000           0.0      0.787757       0.319045  2688.0
# 2689       0.264151           0.0      0.327599       0.139973  2689.0
# 2690       0.000000           1.0      0.708321       0.287638  2690.0
# 2691       0.000000           0.0      0.387374       0.179842  2691.0
# 2692       0.000000           0.0      0.678329       0.278427  2692.0
# 2693       0.318182           0.0      0.827201       0.285320  2693.0
# 2694       0.000000           0.0      0.820234       0.383326  2694.0
# 2695       0.000000           0.0      0.660947       0.271599  2695.0
# 2696       0.000000           1.0      0.660947       0.277387  2696.0
# 2697       0.000000           1.0      0.387374       0.184912  2697.0
# 2698       0.000000           0.0      0.803211       0.307564  2698.0
# 2699       0.000000           1.0      0.745613       0.299622  2699.0
# 2700       0.350000           0.0      0.827201       0.327083  2700.0
# 2701       0.291667           1.0      0.567090       0.271253  2701.0
# 2702       0.000000           0.0      0.803211       0.355696  2702.0
# 2703       0.000000           0.0      0.361670       0.156005  2703.0
#
# [2704 rows x 272 columns]
